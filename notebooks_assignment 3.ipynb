# %%
# Question # 1


# a=int(input("Enter number 1:"))
# b=int(input("Enter number 2:"))
# operator=input("Enter operation (+,-,*,/,**):")
# result = 0 
# if(operator == "+"):
#     result=a+b
#     print(a, "+" ,b ,"=", result )
# elif(operator == "-"):
#     result = a - b
#     print(a, "-" ,b ,"=", result )

# elif(operator == "*"):
#     result = a * b
#     print(a, "*" ,b ,"=", result )
# elif(operator == "/"):
#     result = a / b
#     print(a, "/" ,b ,"=", result )
# elif(operator == "**"):
#     result = a ** b
#     print(a,"^",b ,"=", result )
# else:
#     print("Wrong Operator")



# Question # 2

# list = ["mohsin", "banana", 45, "tomatoes"]

# found_number = False
# value = 0

# for item in list:
#         if type(item) is int or type(item) is float: 
#             found_number = True
#             value = item
#             break

# if found_number:
#     print("The list contains a numeric value.",value)
# else:
#     print("The list does not contain any numeric value.")

# Question # 3

# student = {
#     "name": "Mohsin",
#     "age": 28
# }

# student["city"] = "Karachi"

# print(student)

# Question # 4

# data = {
#     "physics_marks": 60,
#     "computer_marks": 82,
#     "name": "Saad",
#     "gender": "Male",
#     "chemistry_marks":67.5,
#     "isPass": True
# }

# total = 0

# for value in data.values():
#     if type(value) is int or type(value) is float :
#         total += value

# print("Sum of numeric values:", total)


# Question # 5


# list = ["Kalim",3,6,1,"Zain","Akbar",6,2,6,"Akbar","Ahsan",0,1,98]

# removeDuplicates=[]
# duplicates=[]

# for item in list:
#     if item in removeDuplicates:
#         duplicates.append(item)
#     else:
#         removeDuplicates.append(item)

# print("duplicate Item",duplicates)
# print("removeDuplicates",removeDuplicates)


# Question # 6

student = {
    "name": "Ali",
    "age": 37
}

key_to_check = input("Enter key to check:")

if key_to_check.lower() in student:
    print("Key already exists in dictionary.")
else:
    print("Key does not exist.")
# Out:
# Enter key to check: AGE
# Key already exists in dictionary.
